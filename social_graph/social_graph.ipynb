# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('nedznicy.csv')

# %%
plt.style.use('dark_background')

# %%
display(df)
# Out:
#               source           target  value
# 0           Napoleon           Myriel      1
# 1    Mlle.Baptistine           Myriel      8
# 2       Mme.Magloire           Myriel     10
# 3       Mme.Magloire  Mlle.Baptistine      6
# 4       CountessdeLo           Myriel      1
# ..               ...              ...    ...
# 249    Mme.Hucheloup        Grantaire      1
# 250    Mme.Hucheloup          Bahorel      1
# 251    Mme.Hucheloup       Courfeyrac      1
# 252    Mme.Hucheloup         Gavroche      1
# 253    Mme.Hucheloup         Enjolras      1
#
# [254 rows x 3 columns]

# %%
g = nx.Graph()

# %%
#looking for the greatest weight:
tmp = df['value'].tolist()
greatest_value = max(tmp)

# %%
#drawing edges:
for i in range(len(df)):
    g.add_edge(df['source'][i], df['target'][i], weight = df['value'][i])

# %%
sizes = [g.degree(x)*150 for x in list(g)]

# %%
w = [9*x/greatest_value for x in list(nx.get_edge_attributes(g,'weight').values())]


fig, ax = plt.subplots(figsize = (30, 20))

nx.draw_networkx(g, label = True, 
                font_size = 10, 
                 font_weight = 'bold',
                 font_color = 'white',
                node_color = 'firebrick', 
                node_size = sizes,
                width = list(w),
                 edge_color="cornflowerblue", 
                pos = nx.kamada_kawai_layout(g))

plt.title('Social graph of characters from book "Nędznicy"',  fontsize = 30)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)



#plt.savefig('nedznicy_outcome.pdf')
